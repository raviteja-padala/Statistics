# %% [markdown]
# <a href="https://colab.research.google.com/github/raviteja-padala/Statistics/blob/main/Central_Limit_Theorem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Central Limit Theorem
# The Central Limit Theorem (CLT) is a fundamental concept in statistics and probability theory. It states that, under certain conditions, the distribution of the sample means of a sufficiently large number of independent and identically distributed (iid) random variables will approximate a normal distribution, regardless of the shape of the original population distribution.
#
# In simpler terms, the Central Limit Theorem tells us that if we take many random samples from a population and calculate the mean of each sample, the distribution of those sample means will be approximately normal, even if the original population is not normally distributed.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Example 1:
#
# Here's how the Central Limit Theorem comes into play:
#
# 1. **Population Distribution:**
#    Let's assume the population of students has a right-skewed distribution of heights.
#
# 2. **Random Sampling:**
#    We randomly select several samples of different sizes (e.g., 10 students, 20 students, 30 students, etc.) from the population. Each sample is independent of the others.
#
# 3. **Sample Means:**
#    For each sample, we calculate the average height (mean) of the students in that sample.
#
# 4. **Distribution of Sample Means:**
#    As we take more and more samples and calculate the means, we will notice that the distribution of these sample means starts to approximate a normal distribution, regardless of the original population distribution.
#
# 5. **Convergence to Normality:**
#    As the sample size increases, the distribution of sample means gets closer and closer to a normal distribution. This is the essence of the Central Limit Theorem.
#
# For example, the first few samples might not appear normally distributed, but as we take more and more samples and increase the sample size, we observe that the distribution of the sample means becomes more and more bell-shaped, resembling a normal distribution.
#
# This convergence to a normal distribution allows us to make statistical inferences about the population, such as calculating confidence intervals or performing hypothesis tests, using the properties of the normal distribution, even when the population distribution is not normal.
#
# The Central Limit Theorem enables statisticians to draw meaningful conclusions from a sample's average that accurately reflects the population's average, even when the population's distribution is not known or not normally distributed.

# %% [markdown]
# ---

# %%
#importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as stat
from scipy import stats

# %% [markdown]
# ## Example-2: Verifying CLT from random normally-distributed population

# %% [markdown]
# #### Simulating a normally-distributed population

# %%
x = np.random.normal(size=10000) # at default parameters, will be "standard" normal distribution

# %%
sns.histplot(x, kde= True)
plt.title('Normal Distributed population')
plt.show()

# %% [markdown]
# #### Sampling from the normally-distributed population

# %%
#taking a sample from popilation x
x_sample = np.random.choice(x, size=10, replace=False)
x_sample
# Out:
# array([-0.51450237,  0.67293642,  1.00888843,  0.56455192, -0.35911213,
#         2.04336894,  0.13348983, -1.6520922 , -0.59351915, -0.42738318])

# %%
#calculating mean
stat.mean(x_sample)
# Out:
# 0.08766264928986625

# %%
#function to create random samples from population

def sample_mean_calculator(population_array, sample_size, n_samples):
  sample_means = []
  for i in range(n_samples):
    sample = np.random.choice(population_array, size=sample_size, replace=False)
    sample_mean = stat.mean(sample)
    sample_means.append(sample_mean)
  return sample_means

# %% [markdown]
# # Samples from random normal populations and their distributions

# %%
#plottting histogram to see difference as the number of samples increases
fig, axs = plt.subplots(1, 3, figsize=(16, 4))
sns.set(font_scale=1)

sns.histplot(sample_mean_calculator(x, 10, 10), kde=True, color="olive", ax=axs[0])
axs[0].set_title('10 Samples of sample Size 10')

sns.histplot(sample_mean_calculator(x, 10, 1000), kde=True, color="blue", ax=axs[1])
axs[1].set_title('Sample Size 10 , 1000 samples')

sns.histplot(sample_mean_calculator(x, 1000, 1000), kde=True, color="green", ax=axs[2])
axs[2].set_title('Sample Size 1000 , 1000 samples')

plt.show()

# %% [markdown]
# *Observation:*
#
# As the number of samples and the sample size increased , the distribution of those sample means is approximately normal distibuted.

# %% [markdown]
# ## Example-3: Verifying CLT from random skewed population

# %% [markdown]
# #### Simulating a random skewed-distributed population

# %%
from scipy.stats import skewnorm

s = skewnorm.rvs(12, size=10000)

# %%
#plotting sked data s
sns.histplot(s, kde=True)
plt.title('Skewed population')
plt.show()

# %% [markdown]
# # Sampling from a skewed population and their distributions

# %%
#plottting histogram to see difference as the number of samples increases
fig, axs = plt.subplots(1, 3, figsize=(16, 4))
sns.set(font_scale=1)

sns.histplot(sample_mean_calculator(s, 10, 10), kde=True, color="olive", ax=axs[0])
axs[0].set_title('10 Samples of sample Size 10')

sns.histplot(sample_mean_calculator(s, 10, 1000), kde=True, color="blue", ax=axs[1])
axs[1].set_title('Sample Size 10 , 1000 samples')

sns.histplot(sample_mean_calculator(s, 1000, 1000), kde=True, color="green", ax=axs[2])
axs[2].set_title('Sample Size 1000 , 1000 samples')

plt.show()

# %% [markdown]
# *Observation:*
#
# As the number of samples and the sample size increased , the distribution of those sample means is approximately normal distibuted even though the population's distribution is not normally distributed.

# %% [markdown]
# ## Example-4: Verifying CLT from a multinomial distribution

# %% [markdown]
# ## Simulating a multimodal distribution

# %%
m = np.concatenate((np.random.normal(size=10000), np.random.normal(loc = 4.0, size=10000)))

# %%
sns.histplot(m)
plt.title('Multinomial distribution')
plt.show()

# %% [markdown]
# # Samples from a multinomial population and their distributions

# %%
#plottting histogram to see difference as the number of samples increases
fig, axs = plt.subplots(1, 3, figsize=(16, 4))
sns.set(font_scale=1)

sns.histplot(sample_mean_calculator(m, 10, 10), kde=True, color="olive", ax=axs[0])
axs[0].set_title('10 Samples of sample Size 10')

sns.histplot(sample_mean_calculator(m, 10, 1000), kde=True, color="blue", ax=axs[1])
axs[1].set_title('Sample Size 10 , 1000 samples')

sns.histplot(sample_mean_calculator(m, 1000, 1000), kde=True, color="green", ax=axs[2])
axs[2].set_title('Sample Size 1000 , 1000 samples')

plt.show()

# %% [markdown]
# *Observation:*
#
# As the number of samples and the sample size increased , the distribution of those sample means is approximately normal distibuted even though the population's distribution is not normally distributed.

# %% [markdown]
# # Example-5: Verifying CLT from uniform population

# %% [markdown]
# ## Simulating a multimodal distribution

# %%
u = np.random.uniform(size=10000)

# %%
sns.histplot(u, kde=False)
plt.title('Uniform distribution')
plt.show()

# %% [markdown]
# # Samples from a Uniform population and their distributions

# %%
#plottting histogram to see difference as the number of samples increases
fig, axs = plt.subplots(1, 3, figsize=(16, 4))
sns.set(font_scale=1)

sns.histplot(sample_mean_calculator(u, 10, 10), kde=True, color="olive", ax=axs[0])
axs[0].set_title('10 Samples of sample Size 10')

sns.histplot(sample_mean_calculator(u, 10, 1000), kde=True, color="blue", ax=axs[1])
axs[1].set_title('Sample Size 10 , 1000 samples')

sns.histplot(sample_mean_calculator(u, 1000, 1000), kde=True, color="green", ax=axs[2])
axs[2].set_title('Sample Size 1000 , 1000 samples')

plt.show()

# %% [markdown]
# *Observation:*
#
# As the number of samples and the sample size increased , the distribution of those sample means is approximately normal distibuted even though the population's distribution is not normally distributed.

# %% [markdown]
# # Example-6: Verifying CLT from feature of Titanic dataset

# %% [markdown]
# #### importing the dataset

# %%
df = sns.load_dataset('titanic')

# %%
sns.set(rc={'figure.figsize':(8,4)})
sns.histplot(df['fare'], kde=True)
plt.title('Distribution of Fare column')
# Out:
# Text(0.5, 1.0, 'Distribution of Fare column')

# %% [markdown]
# # Samples(Keeping No. of Samples Constant) from the fare column and their distributions

# %%
sample_sizes = [(500,3), (500,10), (500,30), (500,50), (500,100), (500,200)]
list_sample_means = []

# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[16,8])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
    sample_means = [df.fare.sample(samp_size).mean() for i in range(no_of_samples)]
    list_sample_means.append(sample_means)
    plt.subplot(2,3,ind+1)
    sns.histplot(sample_means, bins=25, kde=True, stat="density")
    plt.title("No. of  Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %% [markdown]
# # Samples(Keeping Sample size Constant) from the fare column and their distributions

# %%
sample_sizes = [(50,30), (100,30), (150,30), (200,30), (250,30), (300,30)]
list_sample_means = []

# Plotting the distribution graphs for the above created Samples
plt.figure(figsize=[16,8])
for ind, (no_of_samples,samp_size) in enumerate(sample_sizes):
    sample_means = [df.fare.sample(samp_size).mean() for i in range(no_of_samples)]
    list_sample_means.append(sample_means)
    plt.subplot(2,3,ind+1)
    sns.histplot(sample_means, bins=25, kde=True, stat="density")
    plt.title("No. of  Samples: "+str(no_of_samples) + " Sample size: "+str(samp_size))

# %% [markdown]
# *Observation:*
#
# As the number of samples and the sample size increased , the distribution of those sample means is approximately normal distibuted even though the population's distribution is not normally distributed.

# %% [markdown]
# # Why Is the Central Limit Theorem Useful?
# The central limit theorem is useful when analyzing large data sets because it allows one to assume that the sampling distribution of the mean will be normally-distributed in most cases. This allows for easier statistical analysis and inference. For example, investors can use central limit theorem to aggregate individual security performance data and generate distribution of sample means that represent a larger population distribution for security returns over a period of time.

# %% [markdown]
# # Usage of CLT in Real life scenarios
#
# ##  Economics
# Economists often use the central limit theorem when using sample data to draw conclusions about a population.
#
# For example, an economist may collect a simple random sample of 50 individuals in a town and use the average annual income of the individuals in the sample to estimate the average annual income of individuals in the entire town.
#
# If the economist finds that the average annual income of the individuals in the sample is $58,000, then her best guess for the true average annual income of individuals in the entire town will be $58,000.
#
# ## Biology
# Biologists use the central limit theorem whenever they use data from a sample of organisms to draw conclusions about the overall population of organisms.
#
# For example, a biologist may measure the height of 30 randomly selected plants and then use the sample mean height to estimate the population mean height.
#
# If the biologist finds that the sample mean height of the 30 plants is 10.3 inches, then her best guess for the population mean height will also be 10.3 inches.
#
# ## Manufacturing
# Manufacturing plants often use the central limit theorem to estimate how many products produced by the plant are defective.
#
# For example, the manager of the plant may randomly select 60 products produced by the plant in a given day and count how many of the products are defective. He can use the proportion of defective products in the sample to estimate the proportion of all products that are defective that are produced by the entire plant. If he finds that 2% of products are defective in the sample, then his best guess for the proportion of defective products produced by the entire plant is also 2%.
#
# ## Surveys
# Human Resources departments often use the central limit theorem when using surveys to draw conclusions about overall employee satisfaction at companies.
#
# For example, the HR department of some company may randomly select 50 employees to take a survey that assesses their overall satisfaction on a scale of 1 to 10.
#
# If it’s found that the average satisfaction among employees in the survey is 8.5 then the best guess for the average satisfaction rating of all employees at the company is also 8.5.
#
# ## Agriculture
# Agricultural scientists use the central limit theorem whenever they use data from samples to draw conclusions about a larger population.
#
# For example, an agricultural scientist may test a new fertilizer on 15 different fields and measure the average crop yield of each field.
#
# If it’s found that the average field produces 400 pounds of wheat, then the best guess for the average crop yield for all fields will also be 400 pounds.

# %% [markdown]
# ## Conclusion:
#
# Throughout this study, we have explored the Central Limit Theorem and put it into practice by verifying its principles through practical examples. As a result, we have obtained a comprehensive and thorough understanding of the Central Limit Theorem.

# %% [markdown]
# ### Thank you for reading till the end.

# %% [markdown]
# ## -Raviteja Padala
# https://www.linkedin.com/in/raviteja-padala/
